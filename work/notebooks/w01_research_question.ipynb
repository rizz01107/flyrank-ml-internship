# %% [markdown]
# <a href="https://colab.research.google.com/github/rizz01107/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/rizz01107/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# Lane: Declining Pages Refresh Priority
#
#    I chose this lane because the dataset already includes trend_direction and trend_pct columns that show which pages are declining...

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Decision: Which pages should be refreshed or updated first to improve their search performance.
#
# Who acts on it: The content/SEO team, who set refresh priorities based on this recommendation.
#
# Cost of a wrong call: If the wrong pages are prioritized, actual declining pages get neglected and their performance keeps dropping — the team also wastes time and effort on pages that didn't need attention.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
#
# Total pages: 30,000
# Declining pages: 16,262 (54.2%)
#
# More than half of all pages in this dataset are showing a declining trend, which makes this a substantial, worthwhile problem — a large enough population to build meaningful refresh-priority recommendations for.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# !git clone https://github.com/rizz01107/flyrank-ml-internship.git
# %cd flyrank-ml-internship

import pandas as pd
df = pd.read_csv('data/raw/content_refresh_anonymized.csv')
print("Total pages:", len(df))
print("Declining pages:", (df['trend_direction'] == 'down').sum())
print("Percent declining:", round((df['trend_direction'] == 'down').mean() * 100, 1), "%")
# Out:
# Cloning into 'flyrank-ml-internship'...
# remote: Enumerating objects: 116, done.
# remote: Counting objects: 100% (116/116), done.
# remote: Compressing objects: 100% (72/72), done.
# remote: Total 116 (delta 32), reused 86 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (116/116), 1.82 MiB | 13.28 MiB/s, done.
# Resolving deltas: 100% (32/32), done.
# /content/flyrank-ml-internship/flyrank-ml-internship
# Total pages: 30000
# Declining pages: 16262
# Percent declining: 54.2 %

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# What I can say: This work identifies pages showing observed, measured decline in trend data — a directional signal that supports decision-making for which pages to prioritize for refresh.
#
# What I can't say: I cannot claim this predicts Google's search algorithm, guarantees traffic recovery, or proves a causal reason why a page is declining. The recommendations are decision-support, not certainty — a starting point for the content team to investigate further, not a final answer.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
